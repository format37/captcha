# %%
# https://2captcha.com/demo

# %%
# https://github.com/2captcha/2captcha-python

# %%
from twocaptcha import TwoCaptcha

# %%
solver = TwoCaptcha('my_api_key')

# %% [markdown]
# ![cap_0r.jpg](attachment:cap_0r.jpg)

# %%
result = solver.normal('cap_0r.jpg')

# %%
result
# Out:
# {'captchaId': '71788797047', 'code': 'jqqqr1'}
